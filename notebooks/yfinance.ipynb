# %%
import yfinance as yf
import pandas as pd
from datetime import date, timedelta, datetime as dt
import numpy as np
# Import matplotlib
import matplotlib.pyplot as plt

# %%
from yahoo_fin.stock_info import get_analysts_info
from yahoo_fin.stock_info import *

# %%
# List of all ticks:
sp500_ticks = tickers_sp500()
# sp500_ticks

# %%
# ticker = input("Enter the stock code: ") 
# startdate = input("Enter the start date in the following format (YYYY-MM-DD): ") 
# enddate = input("Enter the end date in the following format (YYYY-MM-DD): ")

# %%
# class stock: 
#     def __init__(self, ticker, startdate, enddate, window)
#         super().__init__(ticker, startdate, enddate, window)
#         self.stocks = {}
      
#     def getData(self, stock):
#         self.stocks[stock.ticker] = stock
#         stock = yf.Ticker(self.ticker)
#         data_df = yf.download(ticker= stock, start= stock.startdate, end= stock.enddate)

# %%
# currentDate = date.today()
# enddate = currentDate.strftime('%Y-%m-%d')
# four_yrs = currentDate - timedelta(days=2016)
# startdate = four_yrs.strftime('%Y-%m-%d')

# %%
# msft = getData("MSFT", startdate, enddate, 2)

# %%
#         data_df.columns = ["OPEN", "HIGH", "LOW", "CLOSE", "Adj Close", "Volume"]
#         daily_close = data_df[['Adj Close']]
#         daily_pct_change = daily_close.pct_change()
#         daily_pct_change.fillna(0, inplace=True)
#         # Calculate the volatility
#         vol = (daily_pct_change.rolling(self.window).std() * np.sqrt(self.window))
#         vol.columns = ["VOLATILITY"]
#         vol.fillna(0, inplace=True)
#         sharesOutstanding = stock.info.get('sharesOutstanding')
#         daily_turnover = data_df[['Volume']]
#         turnover = (daily_turnover/out) 
#         turnover.columns = ["TURNOVER"]
#         data_df["TURNOVER"] = turnover["TURNOVER"]
#         data_df["VOLATILITY"] = vol["VOLATILITY"]
#         data_df = data_df.drop(columns = ["Adj Close", "Volume"])
#         df = data_df.reset_index()
#         df = df.rename(columns = {"Date": "TIMESTAMP"})
#         final_df = df.round({"OPEN": 2, "HIGH": 2, "LOW": 2, "CLOSE": 2})
#         final_df.to_csv("../data/processed/" + self.ticker + ".csv", index = False)
#         print(final_df)

# %%
# currentDate = date.today()
# enddate = currentDate.strftime('%Y-%m-%d')
# four_yrs = currentDate - timedelta(days=2016)
# startdate = four_yrs.strftime('%Y-%m-%d')

# %%
# msft = stock("MSFT", startdate, enddate, 2)
# msft.dataMunging("MSFT")

# %%
ticker = 'MSFT'

# %%
msft= yf.Ticker(ticker)

# %%
currentDate = date.today()
enddate = currentDate.strftime('%Y-%m-%d')

# %%
four_yrs = currentDate - timedelta(days=2016)
startdate = four_yrs.strftime('%Y-%m-%d')

# %%
data_df = yf.download(ticker, start=startdate, end=enddate)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015
_data = get(tickers, datetime.datetime(2006, 10, 1), datetime.datetime(2012, 1, 1))

# %%
# Assign `Adj Close` to `daily_close`
daily_close = data_df[['Adj Close']]
daily_close
# Out:
#              Adj Close
# Date
# 2015-04-06   37.270851
# 2015-04-07   37.252895
# 2015-04-08   37.154232
# 2015-04-09   37.208065
# 2015-04-10   37.423340
# ...                ...
# 2020-10-05  210.380005
# 2020-10-06  205.910004
# 2020-10-07  209.830002
# 2020-10-08  210.580002
# 2020-10-09  215.809998
#
# [1391 rows x 1 columns]

# %%
# Daily returns
daily_pct_change = daily_close.pct_change()
daily_pct_change.fillna(0, inplace=True)

# %%
daily_pct_change
# Out:
#             Adj Close
# Date
# 2015-04-06   0.000000
# 2015-04-07  -0.000482
# 2015-04-08  -0.002648
# 2015-04-09   0.001449
# 2015-04-10   0.005786
# ...               ...
# 2020-10-05   0.020321
# 2020-10-06  -0.021247
# 2020-10-07   0.019037
# 2020-10-08   0.003574
# 2020-10-09   0.024836
#
# [1391 rows x 1 columns]

# %%
# Average True Range

# %%
# Define the minumum of periods to consider 
min_periods = 2

# %%
V = np.sqrt(min_periods) 
V
# Out:
# 1.4142135623730951

# %%
# Calculate the volatility
vol = (daily_pct_change.rolling(min_periods).std() * np.sqrt(min_periods))
vol.columns = ["VOLATILITY"]
vol.fillna(0, inplace=True)
vol
# Out:
#             VOLATILITY
# Date
# 2015-04-06    0.000000
# 2015-04-07    0.000482
# 2015-04-08    0.002167
# 2015-04-09    0.004097
# 2015-04-10    0.004337
# ...                ...
# 2020-10-05    0.049833
# 2020-10-06    0.041568
# 2020-10-07    0.040285
# 2020-10-08    0.015463
# 2020-10-09    0.021262
#
# [1391 rows x 1 columns]

# %%
# Plot the volatility
vol.plot(figsize=(10, 8))

# Show the plot
plt.show()

# %%
out = msft.info.get('sharesOutstanding')

# %%
daily_turnover = data_df[['Volume']]
daily_turnover
# Out:
#               Volume
# Date
# 2015-04-06  39223700
# 2015-04-07  28809400
# 2015-04-08  24753400
# 2015-04-09  25723900
# 2015-04-10  28022000
# ...              ...
# 2020-10-05  21331600
# 2020-10-06  28554300
# 2020-10-07  25681100
# 2020-10-08  19925800
# 2020-10-09  26428000
#
# [1391 rows x 1 columns]

# %%
turnover = (daily_turnover/out) 
turnover.columns = ["TURNOVER"]
turnover
# Out:
#             TURNOVER
# Date
# 2015-04-06  0.005183
# 2015-04-07  0.003807
# 2015-04-08  0.003271
# 2015-04-09  0.003399
# 2015-04-10  0.003703
# ...              ...
# 2020-10-05  0.002819
# 2020-10-06  0.003773
# 2020-10-07  0.003394
# 2020-10-08  0.002633
# 2020-10-09  0.003492
#
# [1391 rows x 1 columns]

# %%
data_df["TURNOVER"] = turnover["TURNOVER"]
data_df["VOLATILITY"] = vol["VOLATILITY"]
data_df = data_df.drop(columns = ["Adj Close", "Volume"])

# %%
df = data_df.reset_index()
df
# Out:
#            Date        OPEN        HIGH         LOW       CLOSE  TURNOVER  \
# 0    2015-04-06   40.340000   41.779999   40.180000   41.549999  0.005183
# 1    2015-04-07   41.610001   41.910000   41.310001   41.529999  0.003807
# 2    2015-04-08   41.459999   41.689999   41.040001   41.419998  0.003271
# 3    2015-04-09   41.250000   41.619999   41.250000   41.480000  0.003399
# 4    2015-04-10   41.630001   41.950001   41.410000   41.720001  0.003703
# ...         ...         ...         ...         ...         ...       ...
# 1386 2020-10-05  207.220001  210.410004  206.979996  210.380005  0.002819
# 1387 2020-10-06  208.820007  210.179993  204.820007  205.910004  0.003773
# 1388 2020-10-07  207.059998  210.110001  206.720001  209.830002  0.003394
# 1389 2020-10-08  210.509995  211.190002  208.320007  210.580002  0.002633
# 1390 2020-10-09  211.229996  215.860001  211.229996  215.809998  0.003492
#
#       VOLATILITY
# 0       0.000000
# 1       0.000482
# 2       0.002167
# 3       0.004097
# 4       0.004337
# ...          ...
# 1386    0.049833
# 1387    0.041568
# 1388    0.040285
# 1389    0.015463
# 1390    0.021262
#
# [1391 rows x 7 columns]

# %%
df = df.rename(columns = {"Date": "TIMESTAMP"})

# %%
new_df = df.round({"OPEN": 2, "HIGH": 2, "LOW": 2, "CLOSE": 2})
new_df
# Out:
#       TIMESTAMP    OPEN    HIGH     LOW   CLOSE  TURNOVER  VOLATILITY
# 0    2015-04-06   40.34   41.78   40.18   41.55  0.005183    0.000000
# 1    2015-04-07   41.61   41.91   41.31   41.53  0.003807    0.000482
# 2    2015-04-08   41.46   41.69   41.04   41.42  0.003271    0.002167
# 3    2015-04-09   41.25   41.62   41.25   41.48  0.003399    0.004097
# 4    2015-04-10   41.63   41.95   41.41   41.72  0.003703    0.004337
# ...         ...     ...     ...     ...     ...       ...         ...
# 1386 2020-10-05  207.22  210.41  206.98  210.38  0.002819    0.049833
# 1387 2020-10-06  208.82  210.18  204.82  205.91  0.003773    0.041568
# 1388 2020-10-07  207.06  210.11  206.72  209.83  0.003394    0.040285
# 1389 2020-10-08  210.51  211.19  208.32  210.58  0.002633    0.015463
# 1390 2020-10-09  211.23  215.86  211.23  215.81  0.003492    0.021262
#
# [1391 rows x 7 columns]

# %%
new_df.to_csv("../data/processed/msft.csv", index = False)

# %% [markdown]
# (#volatillity)

# %% [markdown]
# #### The volatility of a stock is a measurement of the change in variance in the returns of a stock over a specific period of time.
# It is common to compare the volatility of a stock with another stock to get a feel for which may have less risk or to a market index to examine the stock’s volatility in the overall market.

# %%
# stock = yf.Ticker("MSFT")
# stock.info.get('sharesOutstanding')
# Out:
# 7567649792

# %%
# df.columns = ['TIMESTAMP', 'OPEN', "HIGH", "LOW", "CLOSE", ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-84bc5e8ea5b1> in <module>
# ----> 1 df.columns = ['TIMESTAMP', 'OPEN', "HIGH", "LOW", "CLOSE", ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
# data_df.to_csv('../data/external/msft.csv')

# %%
from pymongo import MongoClient

# %%
# Connect to MongoDB
client =  MongoClient("mongodb://localhost:27017")
db = client['yfinance']
collection = db['msft']
new_df.reset_index(inplace=True)
data_dict = new_df.to_dict("records")
# Insert collection
collection.insert_many(data_dict)
